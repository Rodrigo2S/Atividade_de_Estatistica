# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo2S/Atividade_de_Estatistica/blob/main/Atividade_estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import auth
import missingno as msno
from sklearn.covariance import EllipticEnvelope
import seaborn as sns
import matplotlib.pyplot as plt
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
PROJECT_ID = 'ds-project-353020'

# %%
QUERY = f'''WITH usuarios AS (
                SELECT
                    id as user_id,
                    operating_system,
                    salary,
                    credit_score,
                    date_birth,
                    DATE_DIFF(DATE(DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY)), DATE(date_birth), YEAR) as age
                FROM
                `ds-project-353020.app_data.users_profile`
), eventos AS (
                SELECT
                    user_id,
                    SUM(CASE WHEN event_name = 'app.home_view' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_home_view_last_7_days,
                    SUM(CASE WHEN event_name = 'app.home_view' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_home_view_last_15_days,
                    SUM(CASE WHEN event_name = 'app.search' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_searches_last_7_days,
                    SUM(CASE WHEN event_name = 'app.search' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_searches_last_15_days,
                    SUM(CASE WHEN event_name = 'app.search' AND section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_restaurant_searches_last_7_days,
                    SUM(CASE WHEN event_name = 'app.search' AND section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_restaurant_searches_last_15_days,
                    SUM(CASE WHEN event_name = 'app.search' AND section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_supermarket_searches_last_7_days,
                    SUM(CASE WHEN event_name = 'app.search' AND section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) AS qtd_supermarket_searches_last_15_days,
                    SUM(CASE WHEN event_name = 'app.added_to_cart' AND section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) AS sum_total_value_restaurant_add_cart_last_7_days,   
                    SUM(CASE WHEN event_name = 'app.added_to_cart' AND section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) AS sum_total_value_restaurant_add_cart_last_15_days,
                    SUM(CASE WHEN event_name = 'app.added_to_cart' AND section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) AS sum_total_value_supermarket_add_cart_last_7_days,   
                    SUM(CASE WHEN event_name = 'app.added_to_cart' AND section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) AS sum_total_value_supermarket_add_cart_last_15_days    
                FROM
                `ds-project-353020.app_data.events`
                WHERE DATE(date) <= DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) -- selecionando apenas eventos anteriores a data de corte, 7 dia antes da ultima data disponivel na base de dados
                GROUP BY user_id
), pedidos_anteriores AS (
                        SELECT 
                            user_id,
                            SUM(total_value) as sum_total_value_orders,
                            AVG(total_value) as avg_total_value_orders,
                            SUM(CASE WHEN section = 'restaurant' THEN total_value END ) AS sum_total_value_restaurant_orders,
                            SUM(CASE WHEN section = 'supermarket' THEN total_value END ) AS sum_total_value_supermarket_orders,  
                            AVG(CASE WHEN section = 'restaurant' THEN total_value END ) AS avg_total_value_restaurant_orders,
                            AVG(CASE WHEN section = 'supermarket' THEN total_value END ) AS avg_total_value_supermarket_orders,  
                            SUM(CASE WHEN DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as sum_total_value_orders_last_7_days,
                            SUM(CASE WHEN DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as sum_total_value_orders_last_15_days,
                            AVG(CASE WHEN DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as avg_total_value_orders_last_7_days,
                            AVG(CASE WHEN DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as avg_total_value_orders_last_15_days,
                            SUM(CASE WHEN section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as sum_total_value_restaurant_orders_last_7_days,
                            SUM(CASE WHEN section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as sum_total_value_restaurant_orders_last_15_days,
                            SUM(CASE WHEN section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as sum_total_value_supermarket_orders_last_7_days,
                            SUM(CASE WHEN section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN total_value ELSE 0 END) as sum_total_value_supermarket_orders_last_15_days,
                            COUNT(*) as qtd_orders,
                            SUM(CASE WHEN DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) as qtd_orders_last_7_days,
                            SUM(CASE WHEN DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) as qtd_orders_last_15_days,
                            SUM(CASE WHEN section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) as qtd_restaurant_orders_last_7_days,
                            SUM(CASE WHEN section = 'restaurant' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) as qtd_restaurant_orders_last_15_days,
                            SUM(CASE WHEN section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -14 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) as qtd_supermarket_orders_last_7_days,
                            SUM(CASE WHEN section = 'supermarket' AND DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -22 DAY) AND DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) THEN 1 ELSE 0 END) as qtd_supermarket_orders_last_15_days,
                            SUM(CASE WHEN payment_method = 'credit_card' THEN 1 ELSE 0 END) / COALESCE(COUNT(*), 1) AS taxa_credit_card_payments
                        FROM
                            `ds-project-353020.app_data.orders`
                        WHERE DATE(date) <= DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) -- selecionando apenas pedidos anteriores a data de corte, 7 dia antes da ultima data disponivel na base de dados
                        GROUP BY user_id

), target AS (
            SELECT 
                user_id,
                MAX(CASE WHEN DATE(date) BETWEEN DATE_ADD(DATE "2021-05-31", INTERVAL -7 DAY) AND DATE('2021-05-31') THEN 1 ELSE 0 END) AS target
            FROM
            `ds-project-353020.app_data.orders`
            GROUP BY user_id
)
SELECT 
    usuarios.user_id,
    usuarios.operating_system,
    usuarios.salary,
    usuarios.credit_score,
    usuarios.age,
    eventos.qtd_home_view_last_7_days,
    eventos.qtd_home_view_last_15_days,
    eventos.qtd_searches_last_7_days,
    eventos.qtd_searches_last_15_days,
    eventos.qtd_restaurant_searches_last_7_days,
    eventos.qtd_restaurant_searches_last_15_days,
    eventos.qtd_supermarket_searches_last_7_days,
    eventos.qtd_supermarket_searches_last_15_days,
    eventos.sum_total_value_restaurant_add_cart_last_7_days,   
    eventos.sum_total_value_restaurant_add_cart_last_15_days,
    eventos.sum_total_value_supermarket_add_cart_last_7_days,   
    eventos.sum_total_value_supermarket_add_cart_last_15_days,    
    pedidos_anteriores.sum_total_value_orders,
    pedidos_anteriores.avg_total_value_orders,
    pedidos_anteriores.sum_total_value_restaurant_orders,
    pedidos_anteriores.sum_total_value_supermarket_orders,  
    pedidos_anteriores.avg_total_value_restaurant_orders,
    pedidos_anteriores.avg_total_value_supermarket_orders,  
    pedidos_anteriores.sum_total_value_orders_last_7_days,
    pedidos_anteriores.sum_total_value_orders_last_15_days,
    pedidos_anteriores.avg_total_value_orders_last_7_days,
    pedidos_anteriores.avg_total_value_orders_last_15_days,
    pedidos_anteriores.sum_total_value_restaurant_orders_last_7_days,
    pedidos_anteriores.sum_total_value_restaurant_orders_last_15_days,
    pedidos_anteriores.sum_total_value_supermarket_orders_last_7_days,
    pedidos_anteriores.sum_total_value_supermarket_orders_last_15_days,
    pedidos_anteriores.qtd_orders_last_7_days,
    pedidos_anteriores.qtd_orders_last_15_days,
    pedidos_anteriores.qtd_restaurant_orders_last_7_days,
    pedidos_anteriores.qtd_restaurant_orders_last_15_days,
    pedidos_anteriores.qtd_supermarket_orders_last_7_days,
    pedidos_anteriores.qtd_supermarket_orders_last_15_days,
    pedidos_anteriores.taxa_credit_card_payments,
    target.target
FROM 
usuarios
LEFT JOIN
eventos
ON usuarios.user_id = eventos.user_id
LEFT JOIN
pedidos_anteriores
ON usuarios.user_id = pedidos_anteriores.user_id
LEFT JOIN 
target
ON usuarios.user_id = target.user_id 
'''

# %%
df = pd.io.gbq.read_gbq(QUERY, project_id=PROJECT_ID)

# %%
pd.options.display.max_columns = None
df.head()
# Out:
#    user_id operating_system   salary  credit_score  age  \
# 0     8792          android  4682.76           781   47
# 1    15536              ios  2675.78           551   47
# 2    16944              ios  3278.60           814   47
# 3    19636              ios  5209.68           606   47
# 4    19294              ios   126.51           642   47
#
#    qtd_home_view_last_7_days  qtd_home_view_last_15_days  \
# 0                        4.0                        12.0
# 1                        5.0                        12.0
# 2                        6.0                        14.0
# 3                        0.0                         0.0
# 4                        7.0                        16.0
#
#    qtd_searches_last_7_days  qtd_searches_last_15_days  \
# 0                       8.0                       15.0
# 1                      23.0                       45.0
# 2                      19.0                       45.0
# 3                      12.0                       16.0
# 4                      10.0                       17.0
#
#    qtd_restaurant_searches_last_7_days  qtd_restaurant_searches_last_15_days  \
# 0                                  2.0                                   3.0
# 1                                  7.0                                  18.0
# 2                                  7.0                                  16.0
# 3                                 10.0                                  14.0
# 4                                  5.0                                  10.0
#
#    qtd_supermarket_searches_last_7_days  \
# 0                                   1.0
# 1                                   9.0
# 2                                   8.0
# 3                                   0.0
# 4                                   3.0
#
#    qtd_supermarket_searches_last_15_days  \
# 0                                    4.0
# 1                                   15.0
# 2                                   22.0
# 3                                    0.0
# 4                                    3.0
#
#    sum_total_value_restaurant_add_cart_last_7_days  \
# 0                                            84.01
# 1                                           212.00
# 2                                           619.99
# 3                                           986.00
# 4                                           558.99
#
#    sum_total_value_restaurant_add_cart_last_15_days  \
# 0                                            366.20
# 1                                            406.34
# 2                                            880.73
# 3                                           2134.63
# 4                                            889.67
#
#    sum_total_value_supermarket_add_cart_last_7_days  \
# 0                                             11.00
# 1                                            901.00
# 2                                           1530.01
# 3                                              0.00
# 4                                           1240.00
#
#    sum_total_value_supermarket_add_cart_last_15_days  sum_total_value_orders  \
# 0                                             208.17                 2893.98
# 1                                             969.58                 1363.54
# 2                                            1742.91                 2754.75
# 3                                              28.00                 3008.99
# 4                                            2335.11                 4149.73
#
#    avg_total_value_orders  sum_total_value_restaurant_orders  \
# 0               55.653462                             533.99
# 1               29.011489                             504.90
# 2               45.159836                             946.98
# 3              158.367895                            2980.99
# 4              125.749394                            1130.17
#
#    sum_total_value_supermarket_orders  avg_total_value_restaurant_orders  \
# 0                              284.00                          16.181515
# 1                              750.64                          22.950000
# 2                             1799.77                          31.566000
# 3                               28.00                         165.610556
# 4                             3019.56                          45.206800
#
#    avg_total_value_supermarket_orders  sum_total_value_orders_last_7_days  \
# 0                           56.800000                             1067.01
# 1                           35.744762                              752.96
# 2                           64.277500                             1759.35
# 3                           28.000000                              986.00
# 4                          377.445000                             1798.99
#
#    sum_total_value_orders_last_15_days  avg_total_value_orders_last_7_days  \
# 0                              1971.89                           20.519423
# 1                              1014.13                           16.020426
# 2                              2192.71                           28.841803
# 3                              2162.63                           51.894737
# 4                              2700.58                           54.514848
#
#    avg_total_value_orders_last_15_days  \
# 0                            37.920962
# 1                            21.577234
# 2                            35.946066
# 3                           113.822632
# 4                            81.835758
#
#    sum_total_value_restaurant_orders_last_7_days  \
# 0                                          84.01
# 1                                         182.32
# 2                                         505.18
# 3                                         986.00
# 4                                         558.99
#
#    sum_total_value_restaurant_orders_last_15_days  \
# 0                                          366.20
# 1                                          341.68
# 2                                          733.32
# 3                                         2134.63
# 4                                          844.58
#
#    sum_total_value_supermarket_orders_last_7_days  \
# 0                                           11.00
# 1                                          570.64
# 2                                         1248.17
# 3                                            0.00
# 4                                         1240.00
#
#    sum_total_value_supermarket_orders_last_15_days  qtd_orders_last_7_days  \
# 0                                           208.17                    15.0
# 1                                           639.22                    13.0
# 2                                          1451.39                    17.0
# 3                                            28.00                     9.0
# 4                                          1856.00                    13.0
#
#    qtd_orders_last_15_days  qtd_restaurant_orders_last_7_days  \
# 0                     38.0                               10.0
# 1                     27.0                                8.0
# 2                     39.0                                8.0
# 3                     16.0                                9.0
# 4                     22.0                               10.0
#
#    qtd_restaurant_orders_last_15_days  qtd_supermarket_orders_last_7_days  \
# 0                                26.0                                 2.0
# 1                                15.0                                 5.0
# 2                                19.0                                 8.0
# 3                                15.0                                 0.0
# 4                                18.0                                 3.0
#
#    qtd_supermarket_orders_last_15_days  taxa_credit_card_payments  target
# 0                                  4.0                   0.769231     1.0
# 1                                 11.0                   0.851064     1.0
# 2                                 17.0                   0.786885     1.0
# 3                                  1.0                   0.736842     1.0
# 4                                  4.0                   0.818182     1.0

# %%
df.shape
# Out:
# (20000, 39)

# %% [markdown]
# **temos 20 mil linhas e 39 colunas**

# %% [markdown]
# ## Verificando se a quantidade de linhas confere com a quantidade de usuários distintos

# %%
df.user_id.nunique()
# Out:
# 20000

# %%
df.shape[0] == df.user_id.nunique()
# Out:
# True

# %% [markdown]
# ### Verificando o tipo de cada uma das colunas

# %%
df.dtypes
# Out:
# user_id                                                int64
# operating_system                                      object
# salary                                               float64
# credit_score                                           int64
# age                                                    int64
# qtd_home_view_last_7_days                            float64
# qtd_home_view_last_15_days                           float64
# qtd_searches_last_7_days                             float64
# qtd_searches_last_15_days                            float64
# qtd_restaurant_searches_last_7_days                  float64
# qtd_restaurant_searches_last_15_days                 float64
# qtd_supermarket_searches_last_7_days                 float64
# qtd_supermarket_searches_last_15_days                float64
# sum_total_value_restaurant_add_cart_last_7_days      float64
# sum_total_value_restaurant_add_cart_last_15_days     float64
# sum_total_value_supermarket_add_cart_last_7_days     float64
# sum_total_value_supermarket_add_cart_last_15_days    float64
# sum_total_value_orders                               float64
# avg_total_value_orders                               float64
# sum_total_value_restaurant_orders                    float64
# sum_total_value_supermarket_orders                   float64
# avg_total_value_restaurant_orders                    float64
# avg_total_value_supermarket_orders                   float64
# sum_total_value_orders_last_7_days                   float64
# sum_total_value_orders_last_15_days                  float64
# avg_total_value_orders_last_7_days                   float64
# avg_total_value_orders_last_15_days                  float64
# sum_total_value_restaurant_orders_last_7_days        float64
# sum_total_value_restaurant_orders_last_15_days       float64
# sum_total_value_supermarket_orders_last_7_days       float64
# sum_total_value_supermarket_orders_last_15_days      float64
# qtd_orders_last_7_days                               float64
# qtd_orders_last_15_days                              float64
# qtd_restaurant_orders_last_7_days                    float64
# qtd_restaurant_orders_last_15_days                   float64
# qtd_supermarket_orders_last_7_days                   float64
# qtd_supermarket_orders_last_15_days                  float64
# taxa_credit_card_payments                            float64
# target                                               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 39 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   user_id                                            20000 non-null  int64
#  1   operating_system                                   20000 non-null  object
#  2   salary                                             20000 non-null  float64
#  3   credit_score                                       20000 non-null  int64
#  4   age                                                20000 non-null  int64
#  5   qtd_home_view_last_7_days                          19668 non-null  float64
#  6   qtd_home_view_last_15_days                         19668 non-null  float64
#  7   qtd_searches_last_7_days                           19668 non-null  float64
#  8   qtd_searches_last_15_days                          19668 non-null  float64
#  9   qtd_restaurant_searches_last_7_days                19668 non-null  float64
#  10  qtd_restaurant_searches_last_15_days               19668 non-null  float64
#  11  qtd_supermarket_searches_last_7_days               19668 non-null  float64
#  12  qtd_supermarket_searches_last_15_days              19668 non-null  float64
#  13  sum_total_value_restaurant_add_cart_last_7_days    19668 non-null  float64
#  14  sum_total_value_restaurant_add_cart_last_15_days   19668 non-null  float64
#  15  sum_total_value_supermarket_add_cart_last_7_days   19668 non-null  float64
#  16  sum_total_value_supermarket_add_cart_last_15_days  19668 non-null  float64
#  17  sum_total_value_orders                             15397 non-null  float64
#  18  avg_total_value_orders                             15397 non-null  float64
#  19  sum_total_value_restaurant_orders                  9872 non-null   float64
#  20  sum_total_value_supermarket_orders                 7581 non-null   float64
#  21  avg_total_value_restaurant_orders                  9872 non-null   float64
#  22  avg_total_value_supermarket_orders                 7581 non-null   float64
#  23  sum_total_value_orders_last_7_days                 15397 non-null  float64
#  24  sum_total_value_orders_last_15_days                15397 non-null  float64
#  25  avg_total_value_orders_last_7_days                 15397 non-null  float64
#  26  avg_total_value_orders_last_15_days                15397 non-null  float64
#  27  sum_total_value_restaurant_orders_last_7_days      15397 non-null  float64
#  28  sum_total_value_restaurant_orders_last_15_days     15397 non-null  float64
#  29  sum_total_value_supermarket_orders_last_7_days     15397 non-null  float64
#  30  sum_total_value_supermarket_orders_last_15_days    15397 non-null  float64
#  31  qtd_orders_last_7_days                             15397 non-null  float64
#  32  qtd_orders_last_15_days                            15397 non-null  float64
#  33  qtd_restaurant_orders_last_7_days                  15397 non-null  float64
#  34  qtd_restaurant_orders_last_15_days                 15397 non-null  float64
#  35  qtd_supermarket_orders_last_7_days                 15397 non-null  float64
#  36  qtd_supermarket_orders_last_15_days                15397 non-null  float64
#  37  taxa_credit_card_payments                          15397 non-null  float64
#  38  target                                             16442 non-null  float64
# dtypes: float64(35), int64(3), object(1)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Não Achei necessário ajustar o Tipo de nenhuma delas

# %% [markdown]
# ## Verificando as colunas com valores nulos

# %%
# %matplotlib inline
msno.matrix(df.sample(frac=1));

# %%
msno.bar(df.sample(frac=1));

# %%
(100 * df.isnull().sum() / df.shape[0])
# Out:
# user_id                                               0.000
# operating_system                                      0.000
# salary                                                0.000
# credit_score                                          0.000
# age                                                   0.000
# qtd_home_view_last_7_days                             1.660
# qtd_home_view_last_15_days                            1.660
# qtd_searches_last_7_days                              1.660
# qtd_searches_last_15_days                             1.660
# qtd_restaurant_searches_last_7_days                   1.660
# qtd_restaurant_searches_last_15_days                  1.660
# qtd_supermarket_searches_last_7_days                  1.660
# qtd_supermarket_searches_last_15_days                 1.660
# sum_total_value_restaurant_add_cart_last_7_days       1.660
# sum_total_value_restaurant_add_cart_last_15_days      1.660
# sum_total_value_supermarket_add_cart_last_7_days      1.660
# sum_total_value_supermarket_add_cart_last_15_days     1.660
# sum_total_value_orders                               23.015
# avg_total_value_orders                               23.015
# sum_total_value_restaurant_orders                    50.640
# sum_total_value_supermarket_orders                   62.095
# avg_total_value_restaurant_orders                    50.640
# avg_total_value_supermarket_orders                   62.095
# sum_total_value_orders_last_7_days                   23.015
# sum_total_value_orders_last_15_days                  23.015
# avg_total_value_orders_last_7_days                   23.015
# avg_total_value_orders_last_15_days                  23.015
# sum_total_value_restaurant_orders_last_7_days        23.015
# sum_total_value_restaurant_orders_last_15_days       23.015
# sum_total_value_supermarket_orders_last_7_days       23.015
# sum_total_value_supermarket_orders_last_15_days      23.015
# qtd_orders_last_7_days                               23.015
# qtd_orders_last_15_days                              23.015
# qtd_restaurant_orders_last_7_days                    23.015
# qtd_restaurant_orders_last_15_days                   23.015
# qtd_supermarket_orders_last_7_days                   23.015
# qtd_supermarket_orders_last_15_days                  23.015
# taxa_credit_card_payments                            23.015
# target                                               17.790
# dtype: float64

# %% [markdown]
# ### Preenchendo valores nulos com ' 0 ' para não atrapalhar minha bvase de dados

# %%
df.columns
# Out:
# Index(['user_id', 'operating_system', 'salary', 'credit_score', 'age',
#        'qtd_home_view_last_7_days', 'qtd_home_view_last_15_days',
#        'qtd_searches_last_7_days', 'qtd_searches_last_15_days',
#        'qtd_restaurant_searches_last_7_days',
#        'qtd_restaurant_searches_last_15_days',
#        'qtd_supermarket_searches_last_7_days',
#        'qtd_supermarket_searches_last_15_days',
#        'sum_total_value_restaurant_add_cart_last_7_days',
#        'sum_total_value_restaurant_add_cart_last_15_days',
#        'sum_total_value_supermarket_add_cart_last_7_days',
#        'sum_total_value_supermarket_add_cart_last_15_days',
#        'sum_total_value_orders', 'avg_total_value_orders',
#        'sum_total_value_restaurant_orders',
#        'sum_total_value_supermarket_orders',
#        'avg_total_value_restaurant_orders',
#        'avg_total_value_supermarket_orders',
#        'sum_total_value_orders_last_7_days',
#        'sum_total_value_orders_last_15_days',
#        'avg_total_value_orders_last_7_days',
#        'avg_total_value_orders_last_15_days',
#        'sum_total_value_restaurant_orders_last_7_days',
#        'sum_total_value_restaurant_orders_last_15_days',
#        'sum_total_value_supermarket_orders_last_7_days',
#        'sum_total_value_supermarket_orders_last_15_days',
#        'qtd_orders_last_7_days', 'qtd_orders_last_15_days',
#        'qtd_restaurant_orders_last_7_days',
#        'qtd_restaurant_orders_last_15_days',
#        'qtd_supermarket_orders_last_7_days',
#        'qtd_supermarket_orders_last_15_days', 'taxa_credit_card_payments',
#        'target'],
#       dtype='object')

# %%
COLS_TO_FILL = [
'qtd_home_view_last_7_days'    
,'qtd_home_view_last_15_days'                            
,'qtd_searches_last_7_days'                              
,'qtd_searches_last_15_days'                             
,'qtd_restaurant_searches_last_7_days'                   
,'qtd_restaurant_searches_last_15_days'                  
,'qtd_supermarket_searches_last_7_days'                  
,'qtd_supermarket_searches_last_15_days'                 
,'sum_total_value_restaurant_add_cart_last_7_days'       
,'sum_total_value_restaurant_add_cart_last_15_days'      
,'sum_total_value_supermarket_add_cart_last_7_days'      
,'sum_total_value_supermarket_add_cart_last_15_days'     
,'sum_total_value_orders'                                
,'avg_total_value_orders'                                
,'sum_total_value_restaurant_orders'                     
,'sum_total_value_supermarket_orders'                    
,'avg_total_value_restaurant_orders'                     
,'avg_total_value_supermarket_orders'                    
,'sum_total_value_orders_last_7_days'                    
,'sum_total_value_orders_last_15_days'                   
,'avg_total_value_orders_last_7_days'                    
,'avg_total_value_orders_last_15_days'                   
,'sum_total_value_restaurant_orders_last_7_days'         
,'sum_total_value_restaurant_orders_last_15_days'        
,'sum_total_value_supermarket_orders_last_7_days'        
,'sum_total_value_supermarket_orders_last_15_days'       
,'qtd_orders_last_7_days'                                
,'qtd_orders_last_15_days'                               
,'qtd_restaurant_orders_last_7_days'                     
,'qtd_restaurant_orders_last_15_days'                    
,'qtd_supermarket_orders_last_7_days'                    
,'qtd_supermarket_orders_last_15_days'                   
,'taxa_credit_card_payments'                             
,'target'                                                
]

# %%
df['taxa_credit_card_payments'].fillna(df['taxa_credit_card_payments'].dropna().mean(), inplace=True)

# %%
df.fillna(0, inplace=True)

# %%
msno.bar(df.sample(frac=1));

# %% [markdown]
# ### Não temos mais dados nulos

# %% [markdown]
# ## Tratamento das variaveis categóricas

# %%
df = pd.get_dummies(df)

# %%
df.iloc[:,-2:].head()
# Out:
#    operating_system_android  operating_system_ios
# 0                         1                     0
# 1                         0                     1
# 2                         0                     1
# 3                         0                     1
# 4                         0                     1

# %% [markdown]
# # Estatística do dados

# %% [markdown]
# ## Análise descritiva

# %%
df.describe()
# Out:
#             user_id        salary  credit_score           age  \
# count  20000.000000  20000.000000  20000.000000  20000.000000
# mean   10000.500000   3686.973267    614.450550     39.744350
# std     5773.647028   3703.606235     71.920792     17.233585
# min        1.000000      0.000000    424.000000     17.000000
# 25%     5000.750000   1066.070000    559.000000     25.000000
# 50%    10000.500000   2608.065000    601.000000     38.000000
# 75%    15000.250000   5143.165000    663.000000     52.000000
# max    20000.000000  35627.830000    872.000000     79.000000
#
#        qtd_home_view_last_7_days  qtd_home_view_last_15_days  \
# count               20000.000000                20000.000000
# mean                    2.097400                    4.131250
# std                     2.703031                    5.170615
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     1.000000                    2.000000
# 75%                     3.000000                    6.000000
# max                    21.000000                   40.000000
#
#        qtd_searches_last_7_days  qtd_searches_last_15_days  \
# count              20000.000000               20000.000000
# mean                   5.944450                  11.448050
# std                    4.929055                   9.190355
# min                    0.000000                   0.000000
# 25%                    2.000000                   5.000000
# 50%                    5.000000                   9.000000
# 75%                    8.000000                  16.000000
# max                   40.000000                  79.000000
#
#        qtd_restaurant_searches_last_7_days  \
# count                         20000.000000
# mean                              3.245300
# std                               3.536616
# min                               0.000000
# 25%                               1.000000
# 50%                               2.000000
# 75%                               5.000000
# max                              27.000000
#
#        qtd_restaurant_searches_last_15_days  \
# count                          20000.000000
# mean                               6.232450
# std                                6.543352
# min                                0.000000
# 25%                                1.000000
# 50%                                4.000000
# 75%                                9.000000
# max                               64.000000
#
#        qtd_supermarket_searches_last_7_days  \
# count                          20000.000000
# mean                               1.359400
# std                                2.267816
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                2.000000
# max                               21.000000
#
#        qtd_supermarket_searches_last_15_days  \
# count                           20000.000000
# mean                                2.625850
# std                                 4.241929
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 4.000000
# max                                43.000000
#
#        sum_total_value_restaurant_add_cart_last_7_days  \
# count                                     20000.000000
# mean                                        157.471767
# std                                         351.768185
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                         161.992500
# max                                        6545.000000
#
#        sum_total_value_restaurant_add_cart_last_15_days  \
# count                                      20000.000000
# mean                                         309.863688
# std                                          673.293654
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            9.795000
# 75%                                          337.270000
# max                                        13576.000000
#
#        sum_total_value_supermarket_add_cart_last_7_days  \
# count                                      20000.000000
# mean                                         194.238809
# std                                          493.866444
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                          144.000000
# max                                         7172.000000
#
#        sum_total_value_supermarket_add_cart_last_15_days  \
# count                                       20000.000000
# mean                                          389.747987
# std                                           924.149975
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                           361.010000
# max                                         15426.160000
#
#        sum_total_value_orders  avg_total_value_orders  \
# count            20000.000000            20000.000000
# mean               855.283119              125.896642
# std               1480.337822              199.969589
# min                  0.000000                0.000000
# 25%                 22.287500               10.500000
# 50%                296.000000               68.400000
# 75%               1020.467500              160.686667
# max              32187.720000             5473.460000
#
#        sum_total_value_restaurant_orders  sum_total_value_supermarket_orders  \
# count                       20000.000000                        20000.000000
# mean                          342.865267                          448.928766
# std                           813.293246                         1118.235065
# min                             0.000000                            0.000000
# 25%                             0.000000                            0.000000
# 50%                             0.000000                            0.000000
# 75%                           327.552500                          378.000000
# max                         15714.000000                        22090.610000
#
#        avg_total_value_restaurant_orders  avg_total_value_supermarket_orders  \
# count                       20000.000000                        20000.000000
# mean                           66.878756                          113.244087
# std                           150.511552                          253.947125
# min                             0.000000                            0.000000
# 25%                             0.000000                            0.000000
# 50%                             0.000000                            0.000000
# 75%                            77.130000                          135.831250
# max                          4368.000000                         5473.460000
#
#        sum_total_value_orders_last_7_days  \
# count                        20000.000000
# mean                           301.725425
# std                            568.677373
# min                              0.000000
# 25%                              0.000000
# 50%                             72.000000
# 75%                            349.067500
# max                           9549.710000
#
#        sum_total_value_orders_last_15_days  \
# count                         20000.000000
# mean                            601.617431
# std                            1069.473294
# min                               0.000000
# 25%                               0.000000
# 50%                             192.000000
# 75%                             702.020000
# max                           22416.370000
#
#        avg_total_value_orders_last_7_days  \
# count                        20000.000000
# mean                            43.872812
# std                             94.806327
# min                              0.000000
# 25%                              0.000000
# 50%                             14.285714
# 75%                             52.806273
# max                           4368.000000
#
#        avg_total_value_orders_last_15_days  \
# count                         20000.000000
# mean                             88.786541
# std                             160.868378
# min                               0.000000
# 25%                               0.000000
# 50%                              42.000000
# 75%                             110.976562
# max                            5473.460000
#
#        sum_total_value_restaurant_orders_last_7_days  \
# count                                   20000.000000
# mean                                      121.680798
# std                                       307.254976
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                       102.000000
# max                                      5602.070000
#
#        sum_total_value_restaurant_orders_last_15_days  \
# count                                    20000.000000
# mean                                       239.996966
# std                                        581.899897
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                        222.172500
# max                                      13217.250000
#
#        sum_total_value_supermarket_orders_last_7_days  \
# count                                    20000.000000
# mean                                       158.036898
# std                                        439.939269
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                         61.402500
# max                                       6023.000000
#
#        sum_total_value_supermarket_orders_last_15_days  \
# count                                     20000.000000
# mean                                        317.326482
# std                                         815.040992
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                         238.500000
# max                                       13966.930000
#
#        qtd_orders_last_7_days  qtd_orders_last_15_days  \
# count            20000.000000             20000.000000
# mean                 2.124750                 4.175200
# std                  2.872629                 5.393363
# min                  0.000000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  1.000000                 2.000000
# 75%                  3.000000                 6.000000
# max                 24.000000                49.000000
#
#        qtd_restaurant_orders_last_7_days  qtd_restaurant_orders_last_15_days  \
# count                       20000.000000                        20000.000000
# mean                            1.119500                            2.198350
# std                             2.099295                            3.915274
# min                             0.000000                            0.000000
# 25%                             0.000000                            0.000000
# 50%                             0.000000                            0.000000
# 75%                             1.000000                            3.000000
# max                            19.000000                           41.000000
#
#        qtd_supermarket_orders_last_7_days  \
# count                        20000.000000
# mean                             0.638500
# std                              1.416904
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              1.000000
# max                             16.000000
#
#        qtd_supermarket_orders_last_15_days  taxa_credit_card_payments  \
# count                         20000.000000               20000.000000
# mean                              1.249650                   0.721656
# std                               2.662439                   0.230798
# min                               0.000000                   0.000000
# 25%                               0.000000                   0.666667
# 50%                               0.000000                   0.721656
# 75%                               1.000000                   0.866667
# max                              38.000000                   1.000000
#
#              target  operating_system_android  operating_system_ios
# count  20000.000000              20000.000000          20000.000000
# mean       0.769300                  0.696200              0.303800
# std        0.421291                  0.459909              0.459909
# min        0.000000                  0.000000              0.000000
# 25%        1.000000                  0.000000              0.000000
# 50%        1.000000                  1.000000              0.000000
# 75%        1.000000                  1.000000              1.000000
# max        1.000000                  1.000000              1.000000

# %% [markdown]
# Algumas Descobertas após a analise descritiva:
#
#
# *   O salario médio de nossos usuários é por volta de $ 3.686 mil
# *   A idade média nos nossos usuários arredondando é 40 anos
# *   Os usuários fazem em média 6 buscas por semana e 11,6 a 12 a cada 2 semanas
# *   Restaurante é a vertical mais buscada, com média de 3.3 buscas contra 1.4 buscas semanais em supermercados

# %% [markdown]
# ## Probabilidade de um usuário realizar pelo menos um pedido dentro de uma semana

# %% [markdown]
# Essa probabilidade pode ser calculada considerando o nosso **target** que representa exatamente os usuários que realizaram pelo menos uma compra dentro da ultima semana

# %%
df['target'].mean()
# Out:
# 0.7693

# %% [markdown]
# Nossos usuários tem probabilidade de 93% de realizar uma compra em 1 semana

# %% [markdown]
# ## Utilizando Percentis para analisar a quantidade de pedidos realizados

# %%
df['qtd_orders_last_7_days'].describe(percentiles=[.25, .50, .75, .9])
# Out:
# count    20000.000000
# mean         2.124750
# std          2.872629
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# 90%          6.000000
# max         24.000000
# Name: qtd_orders_last_7_days, dtype: float64

# %% [markdown]
# Temos 50% dos usuários com 2 pedidos considerando 7 dias. mas se olharmos a média temos 2.7599 quase 2.76 pedidos em 7 dias a média não é tão afetada pelos usuários que fazem muitos pedidos.
#  A mediana é um pouco diferente e representa um pouco melhor a quantidade de pedido da maioria

# %% [markdown]
# ## Verificando os outliers

# %% [markdown]
# utilizando Elliptic Envelope

# %%
elpenv = EllipticEnvelope(random_state=42, contamination=0.05)

# %%
plt.boxplot(df['user_id'])
plt.show()

# %%
# Returns 1 of inliers, -1 for outliers
df['outlier'] = elpenv.fit_predict(df[[i for i in df.columns if i not in ('user_id')]])

# %%
df
# Out:
#        user_id    salary  credit_score  age  qtd_home_view_last_7_days  \
# 0         8792   4682.76           781   47                        4.0
# 1        15536   2675.78           551   47                        5.0
# 2        16944   3278.60           814   47                        6.0
# 3        19636   5209.68           606   47                        0.0
# 4        19294    126.51           642   47                        7.0
# ...        ...       ...           ...  ...                        ...
# 19995     9397    512.36           540   33                        0.0
# 19996    10943   1776.13           620   33                        0.0
# 19997    17735  10739.01           756   33                       12.0
# 19998    17417   7889.10           641   40                        3.0
# 19999      330   1897.42           694   40                        3.0
#
#        qtd_home_view_last_15_days  qtd_searches_last_7_days  \
# 0                            12.0                       8.0
# 1                            12.0                      23.0
# 2                            14.0                      19.0
# 3                             0.0                      12.0
# 4                            16.0                      10.0
# ...                           ...                       ...
# 19995                         0.0                       0.0
# 19996                         0.0                      11.0
# 19997                        13.0                      23.0
# 19998                         8.0                       2.0
# 19999                        11.0                       8.0
#
#        qtd_searches_last_15_days  qtd_restaurant_searches_last_7_days  \
# 0                           15.0                                  2.0
# 1                           45.0                                  7.0
# 2                           45.0                                  7.0
# 3                           16.0                                 10.0
# 4                           17.0                                  5.0
# ...                          ...                                  ...
# 19995                        3.0                                  0.0
# 19996                       19.0                                 10.0
# 19997                       39.0                                 20.0
# 19998                        6.0                                  1.0
# 19999                       16.0                                  0.0
#
#        qtd_restaurant_searches_last_15_days  \
# 0                                       3.0
# 1                                      18.0
# 2                                      16.0
# 3                                      14.0
# 4                                      10.0
# ...                                     ...
# 19995                                   3.0
# 19996                                  17.0
# 19997                                  33.0
# 19998                                   2.0
# 19999                                   4.0
#
#        qtd_supermarket_searches_last_7_days  \
# 0                                       1.0
# 1                                       9.0
# 2                                       8.0
# 3                                       0.0
# 4                                       3.0
# ...                                     ...
# 19995                                   0.0
# 19996                                   1.0
# 19997                                   0.0
# 19998                                   0.0
# 19999                                   8.0
#
#        qtd_supermarket_searches_last_15_days  \
# 0                                        4.0
# 1                                       15.0
# 2                                       22.0
# 3                                        0.0
# 4                                        3.0
# ...                                      ...
# 19995                                    0.0
# 19996                                    2.0
# 19997                                    0.0
# 19998                                    3.0
# 19999                                   12.0
#
#        sum_total_value_restaurant_add_cart_last_7_days  \
# 0                                                84.01
# 1                                               212.00
# 2                                               619.99
# 3                                               986.00
# 4                                               558.99
# ...                                                ...
# 19995                                           700.00
# 19996                                           450.00
# 19997                                          1692.00
# 19998                                           210.00
# 19999                                           690.00
#
#        sum_total_value_restaurant_add_cart_last_15_days  \
# 0                                                366.20
# 1                                                406.34
# 2                                                880.73
# 3                                               2134.63
# 4                                                889.67
# ...                                                 ...
# 19995                                           1420.00
# 19996                                            617.62
# 19997                                           1802.96
# 19998                                            427.24
# 19999                                            777.63
#
#        sum_total_value_supermarket_add_cart_last_7_days  \
# 0                                                 11.00
# 1                                                901.00
# 2                                               1530.01
# 3                                                  0.00
# 4                                               1240.00
# ...                                                 ...
# 19995                                              0.00
# 19996                                              0.00
# 19997                                              0.00
# 19998                                            924.00
# 19999                                              0.00
#
#        sum_total_value_supermarket_add_cart_last_15_days  \
# 0                                                 208.17
# 1                                                 969.58
# 2                                                1742.91
# 3                                                  28.00
# 4                                                2335.11
# ...                                                  ...
# 19995                                               0.00
# 19996                                               0.00
# 19997                                               0.00
# 19998                                            1590.42
# 19999                                             371.65
#
#        sum_total_value_orders  avg_total_value_orders  \
# 0                     2893.98               55.653462
# 1                     1363.54               29.011489
# 2                     2754.75               45.159836
# 3                     3008.99              158.367895
# 4                     4149.73              125.749394
# ...                       ...                     ...
# 19995                 1940.00              107.777778
# 19996                 1656.00               92.000000
# 19997                 1791.27               89.563500
# 19998                 3036.58              112.465926
# 19999                 4789.11              184.196538
#
#        sum_total_value_restaurant_orders  sum_total_value_supermarket_orders  \
# 0                                 533.99                              284.00
# 1                                 504.90                              750.64
# 2                                 946.98                             1799.77
# 3                                2980.99                               28.00
# 4                                1130.17                             3019.56
# ...                                  ...                                 ...
# 19995                            1940.00                                0.00
# 19996                             802.00                              854.00
# 19997                            1621.26                                0.00
# 19998                             483.58                             2553.00
# 19999                             577.10                             4212.01
#
#        avg_total_value_restaurant_orders  avg_total_value_supermarket_orders  \
# 0                              16.181515                           56.800000
# 1                              22.950000                           35.744762
# 2                              31.566000                           64.277500
# 3                             165.610556                           28.000000
# 4                              45.206800                          377.445000
# ...                                  ...                                 ...
# 19995                         107.777778                            0.000000
# 19996                          53.466667                          284.666667
# 19997                         101.328750                            0.000000
# 19998                          30.223750                          232.090909
# 19999                          30.373684                          601.715714
#
#        sum_total_value_orders_last_7_days  \
# 0                                 1067.01
# 1                                  752.96
# 2                                 1759.35
# 3                                  986.00
# 4                                 1798.99
# ...                                   ...
# 19995                              700.00
# 19996                              450.00
# 19997                             1490.57
# 19998                             1111.89
# 19999                              414.00
#
#        sum_total_value_orders_last_15_days  \
# 0                                  1971.89
# 1                                  1014.13
# 2                                  2192.71
# 3                                  2162.63
# 4                                  2700.58
# ...                                    ...
# 19995                              1420.00
# 19996                               617.62
# 19997                              1712.40
# 19998                              1941.24
# 19999                               868.41
#
#        avg_total_value_orders_last_7_days  \
# 0                               20.519423
# 1                               16.020426
# 2                               28.841803
# 3                               51.894737
# 4                               54.514848
# ...                                   ...
# 19995                           38.888889
# 19996                           25.000000
# 19997                           74.528500
# 19998                           41.181111
# 19999                           15.923077
#
#        avg_total_value_orders_last_15_days  \
# 0                                37.920962
# 1                                21.577234
# 2                                35.946066
# 3                               113.822632
# 4                                81.835758
# ...                                    ...
# 19995                            78.888889
# 19996                            34.312222
# 19997                            85.620000
# 19998                            71.897778
# 19999                            33.400385
#
#        sum_total_value_restaurant_orders_last_7_days  \
# 0                                              84.01
# 1                                             182.32
# 2                                             505.18
# 3                                             986.00
# 4                                             558.99
# ...                                              ...
# 19995                                         700.00
# 19996                                         450.00
# 19997                                        1490.57
# 19998                                         187.89
# 19999                                         414.00
#
#        sum_total_value_restaurant_orders_last_15_days  \
# 0                                              366.20
# 1                                              341.68
# 2                                              733.32
# 3                                             2134.63
# 4                                              844.58
# ...                                               ...
# 19995                                         1420.00
# 19996                                          617.62
# 19997                                         1586.74
# 19998                                          350.82
# 19999                                          496.76
#
#        sum_total_value_supermarket_orders_last_7_days  \
# 0                                               11.00
# 1                                              570.64
# 2                                             1248.17
# 3                                                0.00
# 4                                             1240.00
# ...                                               ...
# 19995                                            0.00
# 19996                                            0.00
# 19997                                            0.00
# 19998                                          924.00
# 19999                                            0.00
#
#        sum_total_value_supermarket_orders_last_15_days  \
# 0                                               208.17
# 1                                               639.22
# 2                                              1451.39
# 3                                                28.00
# 4                                              1856.00
# ...                                                ...
# 19995                                             0.00
# 19996                                             0.00
# 19997                                             0.00
# 19998                                          1590.42
# 19999                                           371.65
#
#        qtd_orders_last_7_days  qtd_orders_last_15_days  \
# 0                        15.0                     38.0
# 1                        13.0                     27.0
# 2                        17.0                     39.0
# 3                         9.0                     16.0
# 4                        13.0                     22.0
# ...                       ...                      ...
# 19995                     6.0                     13.0
# 19996                    11.0                     13.0
# 19997                     5.0                     16.0
# 19998                     9.0                     20.0
# 19999                     5.0                     14.0
#
#        qtd_restaurant_orders_last_7_days  qtd_restaurant_orders_last_15_days  \
# 0                                   10.0                                26.0
# 1                                    8.0                                15.0
# 2                                    8.0                                19.0
# 3                                    9.0                                15.0
# 4                                   10.0                                18.0
# ...                                  ...                                 ...
# 19995                                6.0                                13.0
# 19996                               11.0                                13.0
# 19997                                5.0                                13.0
# 19998                                6.0                                13.0
# 19999                                5.0                                13.0
#
#        qtd_supermarket_orders_last_7_days  \
# 0                                     2.0
# 1                                     5.0
# 2                                     8.0
# 3                                     0.0
# 4                                     3.0
# ...                                   ...
# 19995                                 0.0
# 19996                                 0.0
# 19997                                 0.0
# 19998                                 3.0
# 19999                                 0.0
#
#        qtd_supermarket_orders_last_15_days  taxa_credit_card_payments  target  \
# 0                                      4.0                   0.769231     1.0
# 1                                     11.0                   0.851064     1.0
# 2                                     17.0                   0.786885     1.0
# 3                                      1.0                   0.736842     1.0
# 4                                      4.0                   0.818182     1.0
# ...                                    ...                        ...     ...
# 19995                                  0.0                   0.722222     1.0
# 19996                                  0.0                   0.777778     1.0
# 19997                                  0.0                   0.750000     1.0
# 19998                                  7.0                   0.777778     1.0
# 19999                                  1.0                   0.923077     1.0
#
#        operating_system_android  operating_system_ios  outlier
# 0                             1                     0        1
# 1                             0                     1        1
# 2                             0                     1        1
# 3                             0                     1        1
# 4                             0                     1       -1
# ...                         ...                   ...      ...
# 19995                         0                     1        1
# 19996                         1                     0        1
# 19997                         1                     0        1
# 19998                         1                     0        1
# 19999                         0                     1       -1
#
# [20000 rows x 41 columns]

# %%
df.outlier.value_counts(normalize=True)
# Out:
#  1    0.95
# -1    0.05
# Name: outlier, dtype: float64

# %%
df_clean = df.loc[df.outlier == 1].drop('outlier', axis=1)

# %%
df_clean.shape
# Out:
# (19000, 40)

# %%
df_clean.target.mean()
# Out:
# 0.758

# %% [markdown]
# apos remover outliers temos agora apenas 19 mil linhas

# %% [markdown]
# ### correlação entre as variáveis

# %%
df_clean.corr()
# Out:
#                                                     user_id    salary  \
# user_id                                            1.000000  0.001131
# salary                                             0.001131  1.000000
# credit_score                                       0.001843  0.345256
# age                                               -0.000443 -0.000800
# qtd_home_view_last_7_days                         -0.072788  0.166927
# qtd_home_view_last_15_days                        -0.099402  0.160441
# qtd_searches_last_7_days                          -0.001080  0.176274
# qtd_searches_last_15_days                         -0.002051  0.179437
# qtd_restaurant_searches_last_7_days                0.004744  0.131831
# qtd_restaurant_searches_last_15_days               0.000021  0.133073
# qtd_supermarket_searches_last_7_days              -0.010115  0.115945
# qtd_supermarket_searches_last_15_days             -0.007571  0.118058
# sum_total_value_restaurant_add_cart_last_7_days    0.000421  0.081501
# sum_total_value_restaurant_add_cart_last_15_days   0.000195  0.084132
# sum_total_value_supermarket_add_cart_last_7_days   0.004231  0.127235
# sum_total_value_supermarket_add_cart_last_15_days -0.001914  0.142887
# sum_total_value_orders                            -0.002261  0.178647
# avg_total_value_orders                            -0.003493  0.071296
# sum_total_value_restaurant_orders                 -0.001218  0.109993
# sum_total_value_supermarket_orders                -0.003611  0.154299
# avg_total_value_restaurant_orders                 -0.000592  0.045791
# avg_total_value_supermarket_orders                -0.013249  0.106713
# sum_total_value_orders_last_7_days                 0.007294  0.163568
# sum_total_value_orders_last_15_days                0.002082  0.175511
# avg_total_value_orders_last_7_days                 0.006347  0.060619
# avg_total_value_orders_last_15_days                0.000954  0.063085
# sum_total_value_restaurant_orders_last_7_days      0.001827  0.102262
# sum_total_value_restaurant_orders_last_15_days     0.001797  0.106939
# sum_total_value_supermarket_orders_last_7_days     0.007776  0.132566
# sum_total_value_supermarket_orders_last_15_days    0.000452  0.150903
# qtd_orders_last_7_days                             0.007920  0.163208
# qtd_orders_last_15_days                            0.009024  0.169674
# qtd_restaurant_orders_last_7_days                  0.006096  0.110563
# qtd_restaurant_orders_last_15_days                 0.004606  0.110579
# qtd_supermarket_orders_last_7_days                -0.002000  0.136335
# qtd_supermarket_orders_last_15_days               -0.001202  0.145621
# taxa_credit_card_payments                          0.019971  0.078821
# target                                             0.005420  0.092781
# operating_system_android                           0.001246 -0.072675
# operating_system_ios                              -0.001246  0.072675
#
#                                                    credit_score       age  \
# user_id                                                0.001843 -0.000443
# salary                                                 0.345256 -0.000800
# credit_score                                           1.000000 -0.002757
# age                                                   -0.002757  1.000000
# qtd_home_view_last_7_days                              0.296277 -0.011878
# qtd_home_view_last_15_days                             0.295623 -0.013046
# qtd_searches_last_7_days                               0.352137 -0.003700
# qtd_searches_last_15_days                              0.358974 -0.003847
# qtd_restaurant_searches_last_7_days                    0.271082 -0.006697
# qtd_restaurant_searches_last_15_days                   0.277248 -0.006557
# qtd_supermarket_searches_last_7_days                   0.225927  0.000851
# qtd_supermarket_searches_last_15_days                  0.229756  0.003777
# sum_total_value_restaurant_add_cart_last_7_days        0.158950  0.001705
# sum_total_value_restaurant_add_cart_last_15_days       0.169173 -0.000208
# sum_total_value_supermarket_add_cart_last_7_days       0.251766 -0.006820
# sum_total_value_supermarket_add_cart_last_15_days      0.288333 -0.006103
# sum_total_value_orders                                 0.359315 -0.000617
# avg_total_value_orders                                 0.149823  0.005412
# sum_total_value_restaurant_orders                      0.213192  0.000891
# sum_total_value_supermarket_orders                     0.317672 -0.000392
# avg_total_value_restaurant_orders                      0.085968  0.011503
# avg_total_value_supermarket_orders                     0.213747 -0.000948
# sum_total_value_orders_last_7_days                     0.322267 -0.004243
# sum_total_value_orders_last_15_days                    0.346079 -0.003787
# avg_total_value_orders_last_7_days                     0.114811  0.006890
# avg_total_value_orders_last_15_days                    0.128170  0.004638
# sum_total_value_restaurant_orders_last_7_days          0.195246  0.003979
# sum_total_value_restaurant_orders_last_15_days         0.206258  0.002570
# sum_total_value_supermarket_orders_last_7_days         0.264624 -0.008111
# sum_total_value_supermarket_orders_last_15_days        0.301592 -0.007161
# qtd_orders_last_7_days                                 0.337379 -0.005576
# qtd_orders_last_15_days                                0.350795 -0.001979
# qtd_restaurant_orders_last_7_days                      0.215605 -0.003640
# qtd_restaurant_orders_last_15_days                     0.222814 -0.000808
# qtd_supermarket_orders_last_7_days                     0.290156 -0.005835
# qtd_supermarket_orders_last_15_days                    0.304233 -0.005781
# taxa_credit_card_payments                              0.165783  0.004146
# target                                                 0.190749 -0.004877
# operating_system_android                              -0.146561  0.002063
# operating_system_ios                                   0.146561 -0.002063
#
#                                                    qtd_home_view_last_7_days  \
# user_id                                                            -0.072788
# salary                                                              0.166927
# credit_score                                                        0.296277
# age                                                                -0.011878
# qtd_home_view_last_7_days                                           1.000000
# qtd_home_view_last_15_days                                          0.920859
# qtd_searches_last_7_days                                            0.158080
# qtd_searches_last_15_days                                           0.163112
# qtd_restaurant_searches_last_7_days                                 0.120589
# qtd_restaurant_searches_last_15_days                                0.126593
# qtd_supermarket_searches_last_7_days                                0.098151
# qtd_supermarket_searches_last_15_days                               0.100277
# sum_total_value_restaurant_add_cart_last_7_days                     0.069160
# sum_total_value_restaurant_add_cart_last_15_days                    0.067390
# sum_total_value_supermarket_add_cart_last_7_days                    0.105902
# sum_total_value_supermarket_add_cart_last_15_days                   0.121531
# sum_total_value_orders                                              0.154603
# avg_total_value_orders                                              0.055796
# sum_total_value_restaurant_orders                                   0.089421
# sum_total_value_supermarket_orders                                  0.138502
# avg_total_value_restaurant_orders                                   0.031763
# avg_total_value_supermarket_orders                                  0.084798
# sum_total_value_orders_last_7_days                                  0.139223
# sum_total_value_orders_last_15_days                                 0.146107
# avg_total_value_orders_last_7_days                                  0.043987
# avg_total_value_orders_last_15_days                                 0.042137
# sum_total_value_restaurant_orders_last_7_days                       0.085815
# sum_total_value_restaurant_orders_last_15_days                      0.085557
# sum_total_value_supermarket_orders_last_7_days                      0.111244
# sum_total_value_supermarket_orders_last_15_days                     0.127191
# qtd_orders_last_7_days                                              0.148555
# qtd_orders_last_15_days                                             0.156518
# qtd_restaurant_orders_last_7_days                                   0.099430
# qtd_restaurant_orders_last_15_days                                  0.101951
# qtd_supermarket_orders_last_7_days                                  0.120069
# qtd_supermarket_orders_last_15_days                                 0.127333
# taxa_credit_card_payments                                           0.064977
# target                                                              0.077901
# operating_system_android                                           -0.048733
# operating_system_ios                                                0.048733
#
#                                                    qtd_home_view_last_15_days  \
# user_id                                                             -0.099402
# salary                                                               0.160441
# credit_score                                                         0.295623
# age                                                                 -0.013046
# qtd_home_view_last_7_days                                            0.920859
# qtd_home_view_last_15_days                                           1.000000
# qtd_searches_last_7_days                                             0.156523
# qtd_searches_last_15_days                                            0.162023
# qtd_restaurant_searches_last_7_days                                  0.122730
# qtd_restaurant_searches_last_15_days                                 0.129080
# qtd_supermarket_searches_last_7_days                                 0.098646
# qtd_supermarket_searches_last_15_days                                0.100507
# sum_total_value_restaurant_add_cart_last_7_days                      0.070353
# sum_total_value_restaurant_add_cart_last_15_days                     0.070292
# sum_total_value_supermarket_add_cart_last_7_days                     0.104013
# sum_total_value_supermarket_add_cart_last_15_days                    0.119160
# sum_total_value_orders                                               0.155786
# avg_total_value_orders                                               0.059594
# sum_total_value_restaurant_orders                                    0.094038
# sum_total_value_supermarket_orders                                   0.135406
# avg_total_value_restaurant_orders                                    0.038215
# avg_total_value_supermarket_orders                                   0.085631
# sum_total_value_orders_last_7_days                                   0.137189
# sum_total_value_orders_last_15_days                                  0.145373
# avg_total_value_orders_last_7_days                                   0.042694
# avg_total_value_orders_last_15_days                                  0.041883
# sum_total_value_restaurant_orders_last_7_days                        0.087257
# sum_total_value_restaurant_orders_last_15_days                       0.087844
# sum_total_value_supermarket_orders_last_7_days                       0.107316
# sum_total_value_supermarket_orders_last_15_days                      0.123465
# qtd_orders_last_7_days                                               0.149638
# qtd_orders_last_15_days                                              0.155632
# qtd_restaurant_orders_last_7_days                                    0.103820
# qtd_restaurant_orders_last_15_days                                   0.104608
# qtd_supermarket_orders_last_7_days                                   0.116514
# qtd_supermarket_orders_last_15_days                                  0.124362
# taxa_credit_card_payments                                            0.064491
# target                                                               0.079432
# operating_system_android                                            -0.040415
# operating_system_ios                                                 0.040415
#
#                                                    qtd_searches_last_7_days  \
# user_id                                                           -0.001080
# salary                                                             0.176274
# credit_score                                                       0.352137
# age                                                               -0.003700
# qtd_home_view_last_7_days                                          0.158080
# qtd_home_view_last_15_days                                         0.156523
# qtd_searches_last_7_days                                           1.000000
# qtd_searches_last_15_days                                          0.924896
# qtd_restaurant_searches_last_7_days                                0.799376
# qtd_restaurant_searches_last_15_days                               0.733556
# qtd_supermarket_searches_last_7_days                               0.526926
# qtd_supermarket_searches_last_15_days                              0.494936
# sum_total_value_restaurant_add_cart_last_7_days                    0.247966
# sum_total_value_restaurant_add_cart_last_15_days                   0.258098
# sum_total_value_supermarket_add_cart_last_7_days                   0.304898
# sum_total_value_supermarket_add_cart_last_15_days                  0.336194
# sum_total_value_orders                                             0.425199
# avg_total_value_orders                                             0.160576
# sum_total_value_restaurant_orders                                  0.266231
# sum_total_value_supermarket_orders                                 0.343396
# avg_total_value_restaurant_orders                                  0.129273
# avg_total_value_supermarket_orders                                 0.225686
# sum_total_value_orders_last_7_days                                 0.394416
# sum_total_value_orders_last_15_days                                0.416779
# avg_total_value_orders_last_7_days                                 0.131718
# avg_total_value_orders_last_15_days                                0.144110
# sum_total_value_restaurant_orders_last_7_days                      0.249172
# sum_total_value_restaurant_orders_last_15_days                     0.262554
# sum_total_value_supermarket_orders_last_7_days                     0.300010
# sum_total_value_supermarket_orders_last_15_days                    0.331556
# qtd_orders_last_7_days                                             0.452056
# qtd_orders_last_15_days                                            0.472017
# qtd_restaurant_orders_last_7_days                                  0.289779
# qtd_restaurant_orders_last_15_days                                 0.309413
# qtd_supermarket_orders_last_7_days                                 0.343289
# qtd_supermarket_orders_last_15_days                                0.354125
# taxa_credit_card_payments                                          0.071476
# target                                                             0.303051
# operating_system_android                                          -0.064391
# operating_system_ios                                               0.064391
#
#                                                    qtd_searches_last_15_days  \
# user_id                                                            -0.002051
# salary                                                              0.179437
# credit_score                                                        0.358974
# age                                                                -0.003847
# qtd_home_view_last_7_days                                           0.163112
# qtd_home_view_last_15_days                                          0.162023
# qtd_searches_last_7_days                                            0.924896
# qtd_searches_last_15_days                                           1.000000
# qtd_restaurant_searches_last_7_days                                 0.729236
# qtd_restaurant_searches_last_15_days                                0.797615
# qtd_supermarket_searches_last_7_days                                0.495520
# qtd_supermarket_searches_last_15_days                               0.528520
# sum_total_value_restaurant_add_cart_last_7_days                     0.253669
# sum_total_value_restaurant_add_cart_last_15_days                    0.264418
# sum_total_value_supermarket_add_cart_last_7_days                    0.316090
# sum_total_value_supermarket_add_cart_last_15_days                   0.346860
# sum_total_value_orders                                              0.436246
# avg_total_value_orders                                              0.165858
# sum_total_value_restaurant_orders                                   0.271883
# sum_total_value_supermarket_orders                                  0.355778
# avg_total_value_restaurant_orders                                   0.128173
# avg_total_value_supermarket_orders                                  0.236008
# sum_total_value_orders_last_7_days                                  0.403452
# sum_total_value_orders_last_15_days                                 0.426673
# avg_total_value_orders_last_7_days                                  0.133252
# avg_total_value_orders_last_15_days                                 0.147760
# sum_total_value_restaurant_orders_last_7_days                       0.253334
# sum_total_value_restaurant_orders_last_15_days                      0.268259
# sum_total_value_supermarket_orders_last_7_days                      0.310249
# sum_total_value_supermarket_orders_last_15_days                     0.341653
# qtd_orders_last_7_days                                              0.462054
# qtd_orders_last_15_days                                             0.483679
# qtd_restaurant_orders_last_7_days                                   0.302535
# qtd_restaurant_orders_last_15_days                                  0.322032
# qtd_supermarket_orders_last_7_days                                  0.348241
# qtd_supermarket_orders_last_15_days                                 0.360512
# taxa_credit_card_payments                                           0.071527
# target                                                              0.310197
# operating_system_android                                           -0.068518
# operating_system_ios                                                0.068518
#
#                                                    qtd_restaurant_searches_last_7_days  \
# user_id                                                                       0.004744
# salary                                                                        0.131831
# credit_score                                                                  0.271082
# age                                                                          -0.006697
# qtd_home_view_last_7_days                                                     0.120589
# qtd_home_view_last_15_days                                                    0.122730
# qtd_searches_last_7_days                                                      0.799376
# qtd_searches_last_15_days                                                     0.729236
# qtd_restaurant_searches_last_7_days                                           1.000000
# qtd_restaurant_searches_last_15_days                                          0.908121
# qtd_supermarket_searches_last_7_days                                          0.099629
# qtd_supermarket_searches_last_15_days                                         0.099644
# sum_total_value_restaurant_add_cart_last_7_days                               0.287367
# sum_total_value_restaurant_add_cart_last_15_days                              0.292145
# sum_total_value_supermarket_add_cart_last_7_days                              0.106754
# sum_total_value_supermarket_add_cart_last_15_days                             0.112816
# sum_total_value_orders                                                        0.291213
# avg_total_value_orders                                                        0.096986
# sum_total_value_restaurant_orders                                             0.292326
# sum_total_value_supermarket_orders                                            0.124956
# avg_total_value_restaurant_orders                                             0.154416
# avg_total_value_supermarket_orders                                            0.077126
# sum_total_value_orders_last_7_days                                            0.264920
# sum_total_value_orders_last_15_days                                           0.281090
# avg_total_value_orders_last_7_days                                            0.077353
# avg_total_value_orders_last_15_days                                           0.082930
# sum_total_value_restaurant_orders_last_7_days                                 0.276683
# sum_total_value_restaurant_orders_last_15_days                                0.286217
# sum_total_value_supermarket_orders_last_7_days                                0.114108
# sum_total_value_supermarket_orders_last_15_days                               0.119354
# qtd_orders_last_7_days                                                        0.323659
# qtd_orders_last_15_days                                                       0.339193
# qtd_restaurant_orders_last_7_days                                             0.332076
# qtd_restaurant_orders_last_15_days                                            0.350792
# qtd_supermarket_orders_last_7_days                                            0.119469
# qtd_supermarket_orders_last_15_days                                           0.123710
# taxa_credit_card_payments                                                     0.050588
# target                                                                        0.190210
# operating_system_android                                                     -0.045785
# operating_system_ios                                                          0.045785
#
#                                                    qtd_restaurant_searches_last_15_days  \
# user_id                                                                        0.000021
# salary                                                                         0.133073
# credit_score                                                                   0.277248
# age                                                                           -0.006557
# qtd_home_view_last_7_days                                                      0.126593
# qtd_home_view_last_15_days                                                     0.129080
# qtd_searches_last_7_days                                                       0.733556
# qtd_searches_last_15_days                                                      0.797615
# qtd_restaurant_searches_last_7_days                                            0.908121
# qtd_restaurant_searches_last_15_days                                           1.000000
# qtd_supermarket_searches_last_7_days                                           0.100687
# qtd_supermarket_searches_last_15_days                                          0.101112
# sum_total_value_restaurant_add_cart_last_7_days                                0.296782
# sum_total_value_restaurant_add_cart_last_15_days                               0.302526
# sum_total_value_supermarket_add_cart_last_7_days                               0.111272
# sum_total_value_supermarket_add_cart_last_15_days                              0.116241
# sum_total_value_orders                                                         0.300271
# avg_total_value_orders                                                         0.095382
# sum_total_value_restaurant_orders                                              0.302612
# sum_total_value_supermarket_orders                                             0.129657
# avg_total_value_restaurant_orders                                              0.154529
# avg_total_value_supermarket_orders                                             0.081514
# sum_total_value_orders_last_7_days                                             0.272335
# sum_total_value_orders_last_15_days                                            0.288456
# avg_total_value_orders_last_7_days                                             0.073018
# avg_total_value_orders_last_15_days                                            0.079578
# sum_total_value_restaurant_orders_last_7_days                                  0.284275
# sum_total_value_restaurant_orders_last_15_days                                 0.295249
# sum_total_value_supermarket_orders_last_7_days                                 0.118729
# sum_total_value_supermarket_orders_last_15_days                                0.122594
# qtd_orders_last_7_days                                                         0.336397
# qtd_orders_last_15_days                                                        0.352322
# qtd_restaurant_orders_last_7_days                                              0.351212
# qtd_restaurant_orders_last_15_days                                             0.370389
# qtd_supermarket_orders_last_7_days                                             0.120580
# qtd_supermarket_orders_last_15_days                                            0.123976
# taxa_credit_card_payments                                                      0.051429
# target                                                                         0.193479
# operating_system_android                                                      -0.049099
# operating_system_ios                                                           0.049099
#
#                                                    qtd_supermarket_searches_last_7_days  \
# user_id                                                                       -0.010115
# salary                                                                         0.115945
# credit_score                                                                   0.225927
# age                                                                            0.000851
# qtd_home_view_last_7_days                                                      0.098151
# qtd_home_view_last_15_days                                                     0.098646
# qtd_searches_last_7_days                                                       0.526926
# qtd_searches_last_15_days                                                      0.495520
# qtd_restaurant_searches_last_7_days                                            0.099629
# qtd_restaurant_searches_last_15_days                                           0.100687
# qtd_supermarket_searches_last_7_days                                           1.000000
# qtd_supermarket_searches_last_15_days                                          0.925466
# sum_total_value_restaurant_add_cart_last_7_days                                0.060680
# sum_total_value_restaurant_add_cart_last_15_days                               0.067446
# sum_total_value_supermarket_add_cart_last_7_days                               0.460395
# sum_total_value_supermarket_add_cart_last_15_days                              0.516643
# sum_total_value_orders                                                         0.364552
# avg_total_value_orders                                                         0.202880
# sum_total_value_restaurant_orders                                              0.080181
# sum_total_value_supermarket_orders                                             0.506898
# avg_total_value_restaurant_orders                                              0.031034
# avg_total_value_supermarket_orders                                             0.344581
# sum_total_value_orders_last_7_days                                             0.346911
# sum_total_value_orders_last_15_days                                            0.360926
# avg_total_value_orders_last_7_days                                             0.160304
# avg_total_value_orders_last_15_days                                            0.184664
# sum_total_value_restaurant_orders_last_7_days                                  0.071823
# sum_total_value_restaurant_orders_last_15_days                                 0.078787
# sum_total_value_supermarket_orders_last_7_days                                 0.430202
# sum_total_value_supermarket_orders_last_15_days                                0.489150
# qtd_orders_last_7_days                                                         0.302098
# qtd_orders_last_15_days                                                        0.313048
# qtd_restaurant_orders_last_7_days                                              0.068003
# qtd_restaurant_orders_last_15_days                                             0.073266
# qtd_supermarket_orders_last_7_days                                             0.516390
# qtd_supermarket_orders_last_15_days                                            0.535982
# taxa_credit_card_payments                                                      0.055083
# target                                                                         0.221551
# operating_system_android                                                      -0.052808
# operating_system_ios                                                           0.052808
#
#                                                    qtd_supermarket_searches_last_15_days  \
# user_id                                                                        -0.007571
# salary                                                                          0.118058
# credit_score                                                                    0.229756
# age                                                                             0.003777
# qtd_home_view_last_7_days                                                       0.100277
# qtd_home_view_last_15_days                                                      0.100507
# qtd_searches_last_7_days                                                        0.494936
# qtd_searches_last_15_days                                                       0.528520
# qtd_restaurant_searches_last_7_days                                             0.099644
# qtd_restaurant_searches_last_15_days                                            0.101112
# qtd_supermarket_searches_last_7_days                                            0.925466
# qtd_supermarket_searches_last_15_days                                           1.000000
# sum_total_value_restaurant_add_cart_last_7_days                                 0.059504
# sum_total_value_restaurant_add_cart_last_15_days                                0.064316
# sum_total_value_supermarket_add_cart_last_7_days                                0.476713
# sum_total_value_supermarket_add_cart_last_15_days                               0.534001
# sum_total_value_orders                                                          0.372856
# avg_total_value_orders                                                          0.215199
# sum_total_value_restaurant_orders                                               0.075956
# sum_total_value_supermarket_orders                                              0.526238
# avg_total_value_restaurant_orders                                               0.030262
# avg_total_value_supermarket_orders                                              0.360344
# sum_total_value_orders_last_7_days                                              0.355038
# sum_total_value_orders_last_15_days                                             0.369395
# avg_total_value_orders_last_7_days                                              0.172109
# avg_total_value_orders_last_15_days                                             0.196083
# sum_total_value_restaurant_orders_last_7_days                                   0.069685
# sum_total_value_restaurant_orders_last_15_days                                  0.075975
# sum_total_value_supermarket_orders_last_7_days                                  0.444745
# sum_total_value_supermarket_orders_last_15_days                                 0.505861
# qtd_orders_last_7_days                                                          0.306616
# qtd_orders_last_15_days                                                         0.319024
# qtd_restaurant_orders_last_7_days                                               0.066862
# qtd_restaurant_orders_last_15_days                                              0.070763
# qtd_supermarket_orders_last_7_days                                              0.527986
# qtd_supermarket_orders_last_15_days                                             0.551572
# taxa_credit_card_payments                                                       0.054499
# target                                                                          0.226168
# operating_system_android                                                       -0.055887
# operating_system_ios                                                            0.055887
#
#                                                    sum_total_value_restaurant_add_cart_last_7_days  \
# user_id                                                                                   0.000421
# salary                                                                                    0.081501
# credit_score                                                                              0.158950
# age                                                                                       0.001705
# qtd_home_view_last_7_days                                                                 0.069160
# qtd_home_view_last_15_days                                                                0.070353
# qtd_searches_last_7_days                                                                  0.247966
# qtd_searches_last_15_days                                                                 0.253669
# qtd_restaurant_searches_last_7_days                                                       0.287367
# qtd_restaurant_searches_last_15_days                                                      0.296782
# qtd_supermarket_searches_last_7_days                                                      0.060680
# qtd_supermarket_searches_last_15_days                                                     0.059504
# sum_total_value_restaurant_add_cart_last_7_days                                           1.000000
# sum_total_value_restaurant_add_cart_last_15_days                                          0.883194
# sum_total_value_supermarket_add_cart_last_7_days                                          0.063918
# sum_total_value_supermarket_add_cart_last_15_days                                         0.069566
# sum_total_value_orders                                                                    0.638897
# avg_total_value_orders                                                                    0.282735
# sum_total_value_restaurant_orders                                                         0.828809
# sum_total_value_supermarket_orders                                                        0.074475
# avg_total_value_restaurant_orders                                                         0.544813
# avg_total_value_supermarket_orders                                                        0.049695
# sum_total_value_orders_last_7_days                                                        0.660939
# sum_total_value_orders_last_15_days                                                       0.641234
# avg_total_value_orders_last_7_days                                                        0.292538
# avg_total_value_orders_last_15_days                                                       0.266636
# sum_total_value_restaurant_orders_last_7_days                                             0.942589
# sum_total_value_restaurant_orders_last_15_days                                            0.847260
# sum_total_value_supermarket_orders_last_7_days                                            0.067225
# sum_total_value_supermarket_orders_last_15_days                                           0.073461
# qtd_orders_last_7_days                                                                    0.453629
# qtd_orders_last_15_days                                                                   0.451155
# qtd_restaurant_orders_last_7_days                                                         0.545045
# qtd_restaurant_orders_last_15_days                                                        0.542112
# qtd_supermarket_orders_last_7_days                                                        0.071989
# qtd_supermarket_orders_last_15_days                                                       0.072814
# taxa_credit_card_payments                                                                 0.039073
# target                                                                                    0.235361
# operating_system_android                                                                 -0.029085
# operating_system_ios                                                                      0.029085
#
#                                                    sum_total_value_restaurant_add_cart_last_15_days  \
# user_id                                                                                    0.000195
# salary                                                                                     0.084132
# credit_score                                                                               0.169173
# age                                                                                       -0.000208
# qtd_home_view_last_7_days                                                                  0.067390
# qtd_home_view_last_15_days                                                                 0.070292
# qtd_searches_last_7_days                                                                   0.258098
# qtd_searches_last_15_days                                                                  0.264418
# qtd_restaurant_searches_last_7_days                                                        0.292145
# qtd_restaurant_searches_last_15_days                                                       0.302526
# qtd_supermarket_searches_last_7_days                                                       0.067446
# qtd_supermarket_searches_last_15_days                                                      0.064316
# sum_total_value_restaurant_add_cart_last_7_days                                            0.883194
# sum_total_value_restaurant_add_cart_last_15_days                                           1.000000
# sum_total_value_supermarket_add_cart_last_7_days                                           0.067559
# sum_total_value_supermarket_add_cart_last_15_days                                          0.077970
# sum_total_value_orders                                                                     0.705979
# avg_total_value_orders                                                                     0.303188
# sum_total_value_restaurant_orders                                                          0.916050
# sum_total_value_supermarket_orders                                                         0.080975
# avg_total_value_restaurant_orders                                                          0.596536
# avg_total_value_supermarket_orders                                                         0.053788
# sum_total_value_orders_last_7_days                                                         0.594046
# sum_total_value_orders_last_15_days                                                        0.724523
# avg_total_value_orders_last_7_days                                                         0.215338
# avg_total_value_orders_last_15_days                                                        0.301279
# sum_total_value_restaurant_orders_last_7_days                                              0.833871
# sum_total_value_restaurant_orders_last_15_days                                             0.956651
# sum_total_value_supermarket_orders_last_7_days                                             0.071123
# sum_total_value_supermarket_orders_last_15_days                                            0.082536
# qtd_orders_last_7_days                                                                     0.457672
# qtd_orders_last_15_days                                                                    0.482206
# qtd_restaurant_orders_last_7_days                                                          0.542359
# qtd_restaurant_orders_last_15_days                                                         0.575107
# qtd_supermarket_orders_last_7_days                                                         0.079775
# qtd_supermarket_orders_last_15_days                                                        0.082627
# taxa_credit_card_payments                                                                  0.040810
# target                                                                                     0.242435
# operating_system_android                                                                  -0.029644
# operating_system_ios                                                                       0.029644
#
#                                                    sum_total_value_supermarket_add_cart_last_7_days  \
# user_id                                                                                    0.004231
# salary                                                                                     0.127235
# credit_score                                                                               0.251766
# age                                                                                       -0.006820
# qtd_home_view_last_7_days                                                                  0.105902
# qtd_home_view_last_15_days                                                                 0.104013
# qtd_searches_last_7_days                                                                   0.304898
# qtd_searches_last_15_days                                                                  0.316090
# qtd_restaurant_searches_last_7_days                                                        0.106754
# qtd_restaurant_searches_last_15_days                                                       0.111272
# qtd_supermarket_searches_last_7_days                                                       0.460395
# qtd_supermarket_searches_last_15_days                                                      0.476713
# sum_total_value_restaurant_add_cart_last_7_days                                            0.063918
# sum_total_value_restaurant_add_cart_last_15_days                                           0.067559
# sum_total_value_supermarket_add_cart_last_7_days                                           1.000000
# sum_total_value_supermarket_add_cart_last_15_days                                          0.863047
# sum_total_value_orders                                                                     0.525941
# avg_total_value_orders                                                                     0.316609
# sum_total_value_restaurant_orders                                                          0.086966
# sum_total_value_supermarket_orders                                                         0.772598
# avg_total_value_restaurant_orders                                                          0.036228
# avg_total_value_supermarket_orders                                                         0.501397
# sum_total_value_orders_last_7_days                                                         0.709044
# sum_total_value_orders_last_15_days                                                        0.570381
# avg_total_value_orders_last_7_days                                                         0.422963
# avg_total_value_orders_last_15_days                                                        0.329114
# sum_total_value_restaurant_orders_last_7_days                                              0.077715
# sum_total_value_restaurant_orders_last_15_days                                             0.082960
# sum_total_value_supermarket_orders_last_7_days                                             0.958336
# sum_total_value_supermarket_orders_last_15_days                                            0.827045
# qtd_orders_last_7_days                                                                     0.364614
# qtd_orders_last_15_days                                                                    0.351721
# qtd_restaurant_orders_last_7_days                                                          0.078490
# qtd_restaurant_orders_last_15_days                                                         0.080743
# qtd_supermarket_orders_last_7_days                                                         0.631203
# qtd_supermarket_orders_last_15_days                                                        0.604086
# taxa_credit_card_payments                                                                  0.054835
# target                                                                                     0.200067
# operating_system_android                                                                  -0.049267
# operating_system_ios                                                                       0.049267
#
#                                                    sum_total_value_supermarket_add_cart_last_15_days  \
# user_id                                                                                    -0.001914
# salary                                                                                      0.142887
# credit_score                                                                                0.288333
# age                                                                                        -0.006103
# qtd_home_view_last_7_days                                                                   0.121531
# qtd_home_view_last_15_days                                                                  0.119160
# qtd_searches_last_7_days                                                                    0.336194
# qtd_searches_last_15_days                                                                   0.346860
# qtd_restaurant_searches_last_7_days                                                         0.112816
# qtd_restaurant_searches_last_15_days                                                        0.116241
# ...
# operating_system_ios                                                         0.047755
#
#                                                    qtd_supermarket_orders_last_15_days  \
# user_id                                                                      -0.001202
# salary                                                                        0.145621
# credit_score                                                                  0.304233
# age                                                                          -0.005781
# qtd_home_view_last_7_days                                                     0.127333
# qtd_home_view_last_15_days                                                    0.124362
# qtd_searches_last_7_days                                                      0.354125
# qtd_searches_last_15_days                                                     0.360512
# qtd_restaurant_searches_last_7_days                                           0.123710
# qtd_restaurant_searches_last_15_days                                          0.123976
# qtd_supermarket_searches_last_7_days                                          0.535982
# qtd_supermarket_searches_last_15_days                                         0.551572
# sum_total_value_restaurant_add_cart_last_7_days                               0.072814
# sum_total_value_restaurant_add_cart_last_15_days                              0.082627
# sum_total_value_supermarket_add_cart_last_7_days                              0.604086
# sum_total_value_supermarket_add_cart_last_15_days                             0.711052
# sum_total_value_orders                                                        0.494196
# avg_total_value_orders                                                        0.143580
# sum_total_value_restaurant_orders                                             0.103543
# sum_total_value_supermarket_orders                                            0.694622
# avg_total_value_restaurant_orders                                             0.040967
# avg_total_value_supermarket_orders                                            0.251918
# sum_total_value_orders_last_7_days                                            0.476683
# sum_total_value_orders_last_15_days                                           0.513638
# avg_total_value_orders_last_7_days                                            0.131436
# avg_total_value_orders_last_15_days                                           0.156615
# sum_total_value_restaurant_orders_last_7_days                                 0.089328
# sum_total_value_restaurant_orders_last_15_days                                0.103156
# sum_total_value_supermarket_orders_last_7_days                                0.601012
# sum_total_value_supermarket_orders_last_15_days                               0.706549
# qtd_orders_last_7_days                                                        0.506723
# qtd_orders_last_15_days                                                       0.548157
# qtd_restaurant_orders_last_7_days                                             0.092430
# qtd_restaurant_orders_last_15_days                                            0.098883
# qtd_supermarket_orders_last_7_days                                            0.912444
# qtd_supermarket_orders_last_15_days                                           1.000000
# taxa_credit_card_payments                                                     0.068861
# target                                                                        0.226459
# operating_system_android                                                     -0.054847
# operating_system_ios                                                          0.054847
#
#                                                    taxa_credit_card_payments  \
# user_id                                                             0.019971
# salary                                                              0.078821
# credit_score                                                        0.165783
# age                                                                 0.004146
# qtd_home_view_last_7_days                                           0.064977
# qtd_home_view_last_15_days                                          0.064491
# qtd_searches_last_7_days                                            0.071476
# qtd_searches_last_15_days                                           0.071527
# qtd_restaurant_searches_last_7_days                                 0.050588
# qtd_restaurant_searches_last_15_days                                0.051429
# qtd_supermarket_searches_last_7_days                                0.055083
# qtd_supermarket_searches_last_15_days                               0.054499
# sum_total_value_restaurant_add_cart_last_7_days                     0.039073
# sum_total_value_restaurant_add_cart_last_15_days                    0.040810
# sum_total_value_supermarket_add_cart_last_7_days                    0.054835
# sum_total_value_supermarket_add_cart_last_15_days                   0.062691
# sum_total_value_orders                                              0.082738
# avg_total_value_orders                                              0.022306
# sum_total_value_restaurant_orders                                   0.049351
# sum_total_value_supermarket_orders                                  0.074750
# avg_total_value_restaurant_orders                                   0.021937
# avg_total_value_supermarket_orders                                  0.042222
# sum_total_value_orders_last_7_days                                  0.076271
# sum_total_value_orders_last_15_days                                 0.079469
# avg_total_value_orders_last_7_days                                  0.032730
# avg_total_value_orders_last_15_days                                 0.015406
# sum_total_value_restaurant_orders_last_7_days                       0.048027
# sum_total_value_restaurant_orders_last_15_days                      0.049590
# sum_total_value_supermarket_orders_last_7_days                      0.060876
# sum_total_value_supermarket_orders_last_15_days                     0.068113
# qtd_orders_last_7_days                                              0.076142
# qtd_orders_last_15_days                                             0.078203
# qtd_restaurant_orders_last_7_days                                   0.048090
# qtd_restaurant_orders_last_15_days                                  0.048664
# qtd_supermarket_orders_last_7_days                                  0.064624
# qtd_supermarket_orders_last_15_days                                 0.068861
# taxa_credit_card_payments                                           1.000000
# target                                                              0.006834
# operating_system_android                                           -0.027209
# operating_system_ios                                                0.027209
#
#                                                      target  \
# user_id                                            0.005420
# salary                                             0.092781
# credit_score                                       0.190749
# age                                               -0.004877
# qtd_home_view_last_7_days                          0.077901
# qtd_home_view_last_15_days                         0.079432
# qtd_searches_last_7_days                           0.303051
# qtd_searches_last_15_days                          0.310197
# qtd_restaurant_searches_last_7_days                0.190210
# qtd_restaurant_searches_last_15_days               0.193479
# qtd_supermarket_searches_last_7_days               0.221551
# qtd_supermarket_searches_last_15_days              0.226168
# sum_total_value_restaurant_add_cart_last_7_days    0.235361
# sum_total_value_restaurant_add_cart_last_15_days   0.242435
# sum_total_value_supermarket_add_cart_last_7_days   0.200067
# sum_total_value_supermarket_add_cart_last_15_days  0.229541
# sum_total_value_orders                             0.320073
# avg_total_value_orders                             0.264385
# sum_total_value_restaurant_orders                  0.223898
# sum_total_value_supermarket_orders                 0.226775
# avg_total_value_restaurant_orders                  0.214380
# avg_total_value_supermarket_orders                 0.197387
# sum_total_value_orders_last_7_days                 0.283769
# sum_total_value_orders_last_15_days                0.309581
# avg_total_value_orders_last_7_days                 0.187888
# avg_total_value_orders_last_15_days                0.228186
# sum_total_value_restaurant_orders_last_7_days      0.209573
# sum_total_value_restaurant_orders_last_15_days     0.219289
# sum_total_value_supermarket_orders_last_7_days     0.184326
# sum_total_value_supermarket_orders_last_15_days    0.214363
# qtd_orders_last_7_days                             0.375406
# qtd_orders_last_15_days                            0.392218
# qtd_restaurant_orders_last_7_days                  0.280848
# qtd_restaurant_orders_last_15_days                 0.295926
# qtd_supermarket_orders_last_7_days                 0.218797
# qtd_supermarket_orders_last_15_days                0.226459
# taxa_credit_card_payments                          0.006834
# target                                             1.000000
# operating_system_android                          -0.036041
# operating_system_ios                               0.036041
#
#                                                    operating_system_android  \
# user_id                                                            0.001246
# salary                                                            -0.072675
# credit_score                                                      -0.146561
# age                                                                0.002063
# qtd_home_view_last_7_days                                         -0.048733
# qtd_home_view_last_15_days                                        -0.040415
# qtd_searches_last_7_days                                          -0.064391
# qtd_searches_last_15_days                                         -0.068518
# qtd_restaurant_searches_last_7_days                               -0.045785
# qtd_restaurant_searches_last_15_days                              -0.049099
# qtd_supermarket_searches_last_7_days                              -0.052808
# qtd_supermarket_searches_last_15_days                             -0.055887
# sum_total_value_restaurant_add_cart_last_7_days                   -0.029085
# sum_total_value_restaurant_add_cart_last_15_days                  -0.029644
# sum_total_value_supermarket_add_cart_last_7_days                  -0.049267
# sum_total_value_supermarket_add_cart_last_15_days                 -0.063711
# sum_total_value_orders                                            -0.070094
# avg_total_value_orders                                            -0.036509
# sum_total_value_restaurant_orders                                 -0.039377
# sum_total_value_supermarket_orders                                -0.067280
# avg_total_value_restaurant_orders                                 -0.011603
# avg_total_value_supermarket_orders                                -0.051711
# sum_total_value_orders_last_7_days                                -0.057030
# sum_total_value_orders_last_15_days                               -0.066821
# avg_total_value_orders_last_7_days                                -0.027169
# avg_total_value_orders_last_15_days                               -0.031648
# sum_total_value_restaurant_orders_last_7_days                     -0.036453
# sum_total_value_restaurant_orders_last_15_days                    -0.036704
# sum_total_value_supermarket_orders_last_7_days                    -0.047167
# sum_total_value_supermarket_orders_last_15_days                   -0.063352
# qtd_orders_last_7_days                                            -0.057395
# qtd_orders_last_15_days                                           -0.063126
# qtd_restaurant_orders_last_7_days                                 -0.038784
# qtd_restaurant_orders_last_15_days                                -0.040204
# qtd_supermarket_orders_last_7_days                                -0.047755
# qtd_supermarket_orders_last_15_days                               -0.054847
# taxa_credit_card_payments                                         -0.027209
# target                                                            -0.036041
# operating_system_android                                           1.000000
# operating_system_ios                                              -1.000000
#
#                                                    operating_system_ios
# user_id                                                       -0.001246
# salary                                                         0.072675
# credit_score                                                   0.146561
# age                                                           -0.002063
# qtd_home_view_last_7_days                                      0.048733
# qtd_home_view_last_15_days                                     0.040415
# qtd_searches_last_7_days                                       0.064391
# qtd_searches_last_15_days                                      0.068518
# qtd_restaurant_searches_last_7_days                            0.045785
# qtd_restaurant_searches_last_15_days                           0.049099
# qtd_supermarket_searches_last_7_days                           0.052808
# qtd_supermarket_searches_last_15_days                          0.055887
# sum_total_value_restaurant_add_cart_last_7_days                0.029085
# sum_total_value_restaurant_add_cart_last_15_days               0.029644
# sum_total_value_supermarket_add_cart_last_7_days               0.049267
# sum_total_value_supermarket_add_cart_last_15_days              0.063711
# sum_total_value_orders                                         0.070094
# avg_total_value_orders                                         0.036509
# sum_total_value_restaurant_orders                              0.039377
# sum_total_value_supermarket_orders                             0.067280
# avg_total_value_restaurant_orders                              0.011603
# avg_total_value_supermarket_orders                             0.051711
# sum_total_value_orders_last_7_days                             0.057030
# sum_total_value_orders_last_15_days                            0.066821
# avg_total_value_orders_last_7_days                             0.027169
# avg_total_value_orders_last_15_days                            0.031648
# sum_total_value_restaurant_orders_last_7_days                  0.036453
# sum_total_value_restaurant_orders_last_15_days                 0.036704
# sum_total_value_supermarket_orders_last_7_days                 0.047167
# sum_total_value_supermarket_orders_last_15_days                0.063352
# qtd_orders_last_7_days                                         0.057395
# qtd_orders_last_15_days                                        0.063126
# qtd_restaurant_orders_last_7_days                              0.038784
# qtd_restaurant_orders_last_15_days                             0.040204
# qtd_supermarket_orders_last_7_days                             0.047755
# qtd_supermarket_orders_last_15_days                            0.054847
# taxa_credit_card_payments                                      0.027209
# target                                                         0.036041
# operating_system_android                                      -1.000000
# operating_system_ios                                           1.000000

# %%
def remove_variaveis_correlacionadas(x, threshold):
 
    # calcula a matriz de correlacao
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # itera sobre a matriz e compara as correlacoes
    for a in iters:
        for j in range(a+1):
            item = corr_matrix.iloc[j:(j+1), (a+1):(a+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)

            # se a correlacao é maior que o threshold
            if val >= threshold:
                # Print da correlacao e das variaveis
                print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                drop_cols.append(col.values[0])

    # Drop uma do par de variaveis correlacionadas
    drops = set(drop_cols)
    x = x.drop(columns=drops)
    print('Removed Columns {}'.format(drops))
    return x

# %%
df_clean_2 = remove_variaveis_correlacionadas(df_clean, 0.7)
# Out:
# qtd_home_view_last_15_days | qtd_home_view_last_7_days | 0.92
# qtd_searches_last_15_days | qtd_searches_last_7_days | 0.92
# qtd_restaurant_searches_last_7_days | qtd_searches_last_7_days | 0.8
# qtd_restaurant_searches_last_7_days | qtd_searches_last_15_days | 0.73
# qtd_restaurant_searches_last_15_days | qtd_searches_last_7_days | 0.73
# qtd_restaurant_searches_last_15_days | qtd_searches_last_15_days | 0.8
# qtd_restaurant_searches_last_15_days | qtd_restaurant_searches_last_7_days | 0.91
# qtd_supermarket_searches_last_15_days | qtd_supermarket_searches_last_7_days | 0.93
# sum_total_value_restaurant_add_cart_last_15_days | sum_total_value_restaurant_add_cart_last_7_days | 0.88
# sum_total_value_supermarket_add_cart_last_15_days | sum_total_value_supermarket_add_cart_last_7_days | 0.86
# sum_total_value_orders | sum_total_value_restaurant_add_cart_last_15_days | 0.71
# sum_total_value_restaurant_orders | sum_total_value_restaurant_add_cart_last_7_days | 0.83
# sum_total_value_restaurant_orders | sum_total_value_restaurant_add_cart_last_15_days | 0.92
# sum_total_value_restaurant_orders | sum_total_value_orders | 0.78
# sum_total_value_supermarket_orders | sum_total_value_supermarket_add_cart_last_7_days | 0.77
# sum_total_value_supermarket_orders | sum_total_value_supermarket_add_cart_last_15_days | 0.92
# sum_total_value_orders_last_7_days | sum_total_value_supermarket_add_cart_last_7_days | 0.71
# sum_total_value_orders_last_7_days | sum_total_value_orders | 0.83
# sum_total_value_orders_last_15_days | sum_total_value_restaurant_add_cart_last_15_days | 0.72
# sum_total_value_orders_last_15_days | sum_total_value_orders | 0.95
# sum_total_value_orders_last_15_days | sum_total_value_restaurant_orders | 0.74
# sum_total_value_orders_last_15_days | sum_total_value_orders_last_7_days | 0.87
# avg_total_value_orders_last_15_days | avg_total_value_orders | 0.86
# sum_total_value_restaurant_orders_last_7_days | sum_total_value_restaurant_add_cart_last_7_days | 0.94
# sum_total_value_restaurant_orders_last_7_days | sum_total_value_restaurant_add_cart_last_15_days | 0.83
# sum_total_value_restaurant_orders_last_7_days | sum_total_value_restaurant_orders | 0.85
# sum_total_value_restaurant_orders_last_7_days | sum_total_value_orders_last_7_days | 0.71
# sum_total_value_restaurant_orders_last_15_days | sum_total_value_restaurant_add_cart_last_7_days | 0.85
# sum_total_value_restaurant_orders_last_15_days | sum_total_value_restaurant_add_cart_last_15_days | 0.96
# sum_total_value_restaurant_orders_last_15_days | sum_total_value_orders | 0.75
# sum_total_value_restaurant_orders_last_15_days | sum_total_value_restaurant_orders | 0.95
# sum_total_value_restaurant_orders_last_15_days | sum_total_value_orders_last_15_days | 0.77
# sum_total_value_restaurant_orders_last_15_days | sum_total_value_restaurant_orders_last_7_days | 0.87
# sum_total_value_supermarket_orders_last_7_days | sum_total_value_supermarket_add_cart_last_7_days | 0.96
# sum_total_value_supermarket_orders_last_7_days | sum_total_value_supermarket_add_cart_last_15_days | 0.83
# sum_total_value_supermarket_orders_last_7_days | sum_total_value_supermarket_orders | 0.78
# sum_total_value_supermarket_orders_last_7_days | sum_total_value_orders_last_7_days | 0.74
# sum_total_value_supermarket_orders_last_15_days | sum_total_value_supermarket_add_cart_last_7_days | 0.83
# sum_total_value_supermarket_orders_last_15_days | sum_total_value_supermarket_add_cart_last_15_days | 0.98
# sum_total_value_supermarket_orders_last_15_days | sum_total_value_supermarket_orders | 0.93
# sum_total_value_supermarket_orders_last_15_days | sum_total_value_supermarket_orders_last_7_days | 0.85
# qtd_orders_last_15_days | qtd_orders_last_7_days | 0.92
# qtd_restaurant_orders_last_7_days | qtd_orders_last_7_days | 0.81
# qtd_restaurant_orders_last_7_days | qtd_orders_last_15_days | 0.75
# qtd_restaurant_orders_last_15_days | qtd_orders_last_7_days | 0.76
# qtd_restaurant_orders_last_15_days | qtd_orders_last_15_days | 0.82
# qtd_restaurant_orders_last_15_days | qtd_restaurant_orders_last_7_days | 0.92
# qtd_supermarket_orders_last_15_days | sum_total_value_supermarket_add_cart_last_15_days | 0.71
# qtd_supermarket_orders_last_15_days | sum_total_value_supermarket_orders_last_15_days | 0.71
# qtd_supermarket_orders_last_15_days | qtd_supermarket_orders_last_7_days | 0.91
# operating_system_ios | operating_system_android | 1.0
# Removed Columns {'qtd_restaurant_orders_last_7_days', 'qtd_restaurant_searches_last_7_days', 'sum_total_value_supermarket_add_cart_last_15_days', 'sum_total_value_supermarket_orders_last_15_days', 'qtd_restaurant_orders_last_15_days', 'qtd_supermarket_searches_last_15_days', 'sum_total_value_restaurant_orders_last_15_days', 'sum_total_value_supermarket_orders', 'avg_total_value_orders_last_15_days', 'qtd_searches_last_15_days', 'sum_total_value_orders_last_7_days', 'qtd_supermarket_orders_last_15_days', 'qtd_orders_last_15_days', 'operating_system_ios', 'sum_total_value_orders', 'sum_total_value_restaurant_orders', 'qtd_home_view_last_15_days', 'sum_total_value_supermarket_orders_last_7_days', 'sum_total_value_restaurant_orders_last_7_days', 'sum_total_value_orders_last_15_days', 'sum_total_value_restaurant_add_cart_last_15_days', 'qtd_restaurant_searches_last_15_days'}

# %%
df_clean_2.shape
# Out:
# (19000, 18)

# %%
df_clean.shape
# Out:
# (19000, 40)

# %%
df.shape
# Out:
# (20000, 41)

# %%
sns.set(rc={'figure.figsize':(20,12)})
sns.heatmap(df_clean.drop(['user_id', 'target' ], axis=1).corr(), annot=True);

# %% [markdown]
# Plotando o set de variável sem as correlações

# %%
sns.set(rc={'figure.figsize':(20,12)})
sns.heatmap(df_clean_2.drop(['user_id', 'target' ], axis=1).corr(), annot=True);
